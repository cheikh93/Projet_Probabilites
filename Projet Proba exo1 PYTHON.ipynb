# %%
from matplotlib.pyplot import*
from math import*
from numpy import*
from numpy.random import*
from scipy.stats import*
import scipy.stats

# %%
N=5000
n=100
Y=10*rand(1,n)
Y
# Out:
# array([[7.61476419e+00, 6.70557524e+00, 7.78953382e+00, 8.95580175e+00,
#         9.01882734e+00, 1.11086112e+00, 7.31213824e+00, 1.95457148e+00,
#         5.09580660e+00, 5.50465395e+00, 3.59990720e+00, 2.59370500e+00,
#         5.12233561e+00, 3.14867541e+00, 7.72232022e+00, 5.33715057e+00,
#         2.92298861e+00, 7.58768811e+00, 8.13586331e+00, 2.33673526e+00,
#         3.05629141e+00, 1.35522583e+00, 9.26381860e+00, 1.23923583e+00,
#         1.52766365e+00, 6.03804176e+00, 7.51430615e-01, 1.62874909e+00,
#         7.57635362e+00, 3.21818581e+00, 2.89710661e+00, 5.86406232e+00,
#         3.15997958e+00, 1.13589290e+00, 9.45790356e+00, 9.46417823e+00,
#         7.63861724e+00, 4.57410351e-01, 2.71253831e+00, 8.20739582e+00,
#         7.33715702e+00, 4.23451585e-03, 7.45416847e-01, 3.94648029e+00,
#         8.38686366e+00, 7.36356396e+00, 9.71478994e+00, 3.23714987e+00,
#         4.33575431e+00, 1.14743257e+00, 5.93814441e+00, 9.84637389e+00,
# ...

# %%
yn=sum(Y)/n
yn
# Out:
# 4.8343778511711175

# %%
Y=np.zeros((N,n))
for i in range(0,N):
    Y[i]=10*rand(1,n)
Y
# Out:
# array([[6.98841272, 1.63687426, 2.79478663, ..., 5.65282158, 8.11502628,
#         8.29303644],
#        [7.07910593, 2.0608558 , 5.18847143, ..., 2.42643935, 0.7941884 ,
#         2.39313572],
#        [5.16250482, 9.35338984, 5.78227643, ..., 7.84231995, 2.18256442,
#         5.06904826],
#        ...,
#        [3.65400545, 2.55154392, 9.44060168, ..., 8.63090285, 4.28221982,
#         4.18819859],
#        [9.8709994 , 2.63137576, 9.67718513, ..., 8.58511464, 0.42013592,
#         6.25453922],
#        [1.01404169, 7.15590437, 7.87124981, ..., 2.78469183, 7.2536203 ,
#         0.81343063]])

# %%
yn=np.zeros(N)
for i in range(0,N):
    yn[i]=sum(Y[i])/n
yn
# Out:
# array([4.9692834 , 5.33860881, 5.07247255, ..., 4.99996128, 5.09019588,
#        4.84211169])

# %%
figure(figsize=(10,10))
hist(yn,bins=linspace(min(yn),max(yn),50),density=True);
title('Histogramme des 5000 réalisation de $\overline{y_n}$',fontsize=30,color="blue")
# Out:
# Text(0.5, 1.0, 'Histogramme des 5000 réalisation de $\\overline{y_n}$')

# %%
N=10000
n=10
zn=np.zeros(N)
for i in range(0,N-1):
    Y=10*rand(1,n)
    zn[i]=sum(Y)
yn=zn/n
figure(figsize=(10,10))
hist(yn,bins=linspace(min(yn),max(yn),50),density=True);
title('Histogramme des 10000 réalisation de $\overline{Y}_n$ avec $n=10$',fontsize=30,color="blue")
# Out:
# Text(0.5, 1.0, 'Histogramme des 10000 réalisation de $\\overline{Y}_n$ avec $n=10$')

# %%
N=10000
n=1000
zn=np.zeros(N)
for i in range(0,N):
    Y=10*rand(1,n)
    zn[i]=sum(Y)
yn=zn/n
yn
figure(figsize=(10,10))
hist(yn,bins=linspace(min(yn),max(yn),50),density=True);
title('Histogramme des 10000 réalisation de $\overline{Y}_n$ avec n=1000',fontsize=30,color="blue")
# Out:
# Text(0.5, 1.0, 'Histogramme des 10000 réalisation de $\\overline{Y}_n$ avec n=1000')

# %%
N=10000
n=10000
zn=np.zeros(N)
for i in range(0,N):
    Y=10*rand(1,n)
    zn[i]=sum(Y)
yn=zn/n
yn
figure(figsize=(10,10))
hist(yn,bins=linspace(min(yn),max(yn),50),density=True);
title('Histogramme des 10000 réalisation de $\overline{Y}_n$ avec $n=10000$',fontsize=30,color="blue")
# Out:
# Text(0.5, 1.0, 'Histogramme des 10000 réalisation de $\\overline{Y}_n$ avec $n=10000$')
